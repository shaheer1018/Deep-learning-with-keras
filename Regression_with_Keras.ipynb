# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Fetch Data

# %%
concrete_data = pd.read_csv('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv')

# %% [markdown]
# # Explore Data

# %%
concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
# check for missing values
concrete_data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %%
concrete_data.shape
# Out:
# (1030, 9)

# %%
concrete_data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# ...

# %% [markdown]
# # Separate predictor columns and target column

# %%
concrete_data_columns = concrete_data.columns

# predictors are all columns except strength
predictors = concrete_data[concrete_data_columns[concrete_data_columns != "Strength"]]

# target column
target = concrete_data["Strength"]

# %%
predictors.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %%
target.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %% [markdown]
# # Normalize the predictor columns

# %%
# normalize the data by subtracting mean and dividing by standard deviation
predictors_normalized = (predictors - predictors.mean()) / predictors.std()

# %%
predictors_normalized.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %%
# number of predictors
n_predictors = predictors_normalized.shape[1]

# %%
print(n_predictors)
# Out:
# 8

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# # Define Model

# %%
# define regression model
def regression_model():
  # create model
  model = Sequential()
  model.add(Dense(50, activation = 'relu', input_shape = (n_predictors, )))
  model.add(Dense(50, activation = 'relu'))
  model.add(Dense(1))

  # compile model
  model.compile(optimizer = 'adam', loss = 'mean_squared_error')

  return model

# %% [markdown]
# # Train and Test the Network

# %%
# build the model
model = regression_model()

# %%
# train and test the model
model.fit(predictors_normalized, target, validation_split = 0.3, epochs = 100, verbose = 2)
# Out:
# Epoch 1/100
# 23/23 - 1s - loss: 1663.0447 - val_loss: 1159.7535 - 1s/epoch - 48ms/step
# Epoch 2/100
# 23/23 - 0s - loss: 1543.2261 - val_loss: 1047.1785 - 88ms/epoch - 4ms/step
# Epoch 3/100
# 23/23 - 0s - loss: 1339.9574 - val_loss: 860.9858 - 78ms/epoch - 3ms/step
# Epoch 4/100
# 23/23 - 0s - loss: 1015.1881 - val_loss: 612.6065 - 78ms/epoch - 3ms/step
# Epoch 5/100
# 23/23 - 0s - loss: 638.5200 - val_loss: 374.0893 - 79ms/epoch - 3ms/step
# Epoch 6/100
# 23/23 - 0s - loss: 358.8153 - val_loss: 231.1389 - 80ms/epoch - 3ms/step
# Epoch 7/100
# 23/23 - 0s - loss: 246.2341 - val_loss: 196.4765 - 73ms/epoch - 3ms/step
# Epoch 8/100
# 23/23 - 0s - loss: 224.7145 - val_loss: 187.6723 - 81ms/epoch - 4ms/step
# Epoch 9/100
# 23/23 - 0s - loss: 211.3268 - val_loss: 189.8352 - 79ms/epoch - 3ms/step
# Epoch 10/100
# 23/23 - 0s - loss: 200.3183 - val_loss: 185.3209 - 70ms/epoch - 3ms/step
# Epoch 11/100
# 23/23 - 0s - loss: 192.8648 - val_loss: 183.4713 - 84ms/epoch - 4ms/step
# ...
